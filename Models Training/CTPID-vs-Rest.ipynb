# %%
# Import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import loguniform

# Preprocessing and feature selection
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, LabelBinarizer, MinMaxScaler
from sklearn.feature_selection import RFE, VarianceThreshold
from sklearn.inspection import permutation_importance
from sklearn.manifold import TSNE

# Model selection and evaluation
from sklearn.model_selection import cross_val_predict, train_test_split, StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, f1_score, confusion_matrix, precision_recall_curve, make_scorer, ConfusionMatrixDisplay

# Resampling techniques
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# Classifiers
from sklearn.linear_model import RidgeClassifier, LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier, VotingClassifier, GradientBoostingClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.base import BaseEstimator, ClassifierMixin
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier

# SHapley Additive exPlanations
import shap

# %% [markdown]
# # Step1: Load DataSet

# %%
# Read the Data Set
path = 'df_faults_even.xlsx'
DF_faulty = pd.read_excel(path, index_col=0) # With New Features

# %%
# Data Preparation
df_trial = DF_faulty.copy()

# Retain only the samples of 'CTPID', 'N'
remaining_faults = ['CTPID', 'N']
df_trial = df_trial[df_trial['Fault'].isin(remaining_faults)]

X_full = df_trial.drop(columns=['Datetime', 'Fault'])
y_full = df_trial["Fault"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_full, y_full, test_size=0.2, random_state=42, stratify=y_full)

# Training sets
train_df = X_train.copy()
train_df['Fault'] = y_train

# Testing set
test_df = X_test.copy()
test_df['Fault'] = y_test

# Shape
print(f"Training DataFrame shape: {train_df.shape}")
print(f"Testing DataFrame shape: {test_df.shape}")

# Class distribution of training dataset
class_distribution = train_df['Fault'].value_counts()
print("Class distribution in the training set:")
print(class_distribution)

# Class distribution of testing dataset
class_distribution_test = test_df['Fault'].value_counts()
print("Class distribution in the testing set:")
print(class_distribution_test)
# Out:
# Training DataFrame shape: (14014, 114)
# Testing DataFrame shape: (3504, 114)
# Class distribution in the training set:
# Fault
# N        7007
# CTPID    7007
# Name: count, dtype: int64
# Class distribution in the testing set:
# Fault
# N        1752
# CTPID    1752
# Name: count, dtype: int64

# %%
# Prepare Data (Training and Testing)
df_train = train_df.copy()
df_test = test_df.copy()

# Features
X_train = df_train.drop(columns=['Fault'])
X_test = df_test.drop(columns=['Fault'])

# Label Encoding
encoder = LabelEncoder()
y_train_encoded = encoder.fit_transform(df_train['Fault'])
y_test_encoded = encoder.transform(df_test['Fault'])

# Define the target faults for binary classification (CTPID vs Rest)
target_faults = encoder.transform(["CTPID"])  # 1:CTPID, 0:Rest
y_train_binary = np.where(np.isin(y_train_encoded, target_faults), 1, 0)
y_test_binary = np.where(np.isin(y_test_encoded, target_faults), 1, 0)

# %% [markdown]
# # Step2: Training Phase

# %% [markdown]
# # Algorithm Selection

# %%
# Define models
models = {
    "GB": GradientBoostingClassifier(random_state=42),
    "DT": DecisionTreeClassifier(random_state=42),
    "RF": RandomForestClassifier(random_state=42, n_jobs=-1),
    "XGB": XGBClassifier(random_state=42, n_jobs=-1),
    "LightGBM": LGBMClassifier(random_state=42, n_jobs=-1, verbosity=-1),
    "CatBoost": CatBoostClassifier(random_state=42, verbose=0, thread_count=-1),
}

# Stratified 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for model_name, model in models.items():

    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('smote', SMOTE(random_state=42)),
        ('classifier', model)
    ])
    
    # CV F1 scores (positive class)
    cv_f1_scores = cross_val_score(pipeline,X_train,y_train_binary,cv=cv,scoring='f1', n_jobs=-1)
    
    print(f"{model_name}: Mean F1 Score = {np.mean(cv_f1_scores):.4f}")
# Out:
# GB: Mean F1 Score = 0.7216
# DT: Mean F1 Score = 0.7131
# RF: Mean F1 Score = 0.6766
# XGB: Mean F1 Score = 0.7332
# LightGBM: Mean F1 Score = 0.7394
# CatBoost: Mean F1 Score = 0.7453

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Feature Importances with Cross-Validation

# %%
# Stratified 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

feature_importances = []
for train_idx, val_idx in cv.split(X_train, y_train_binary):
    X_cv_train, X_cv_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_cv_train, y_cv_val = y_train_binary[train_idx], y_train_binary[val_idx]
    
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('smote', SMOTE(random_state=42)),
        ('classifier', CatBoostClassifier(random_state=42, verbose=0, thread_count=-1))
    ])
    pipeline.fit(X_cv_train, y_cv_train)

    feature_importances.append(pipeline.named_steps['classifier'].feature_importances_) # Aggregate the Feature Importances

# Average of Feature Importances
mean_importances = np.mean(feature_importances, axis=0)

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': mean_importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                Feature  Importance
# 88          CT_Error_1   27.121247
# 106         CDWL_Error   14.942521
# 30   CT_FAN_SPD_CTRL_1    5.346627
# 36            CT_POW_1    5.081484
# 27        CT_FAN_SPD_1    4.317377
# ..                 ...         ...
# 52    CWL_PRI_PM_POW_3    0.000031
# 42            CT_STA_1    0.000000
# 18           CHL_STA_1    0.000000
# 63    CWL_SEC_PM_STA_1    0.000000
# 3        CDWL_PM_POW_3    0.000000
#
# [113 rows x 2 columns]

# %% [markdown]
# ### Feature Importances Visuazliation

# %%
# Number of features to show
TOP_N = 17
top_features = feature_importance_df.head(TOP_N)['Feature'].tolist()
print(top_features)

# Plot Feature Importances Graph
plt.figure(figsize=(12, 6))
plt.bar(feature_importance_df.head(TOP_N)['Feature'], 
        feature_importance_df.head(TOP_N)['Importance'], 
        color='skyblue')
plt.ylabel('Importance')
plt.xlabel('Feature')
plt.title(f'Top {TOP_N} Feature Importances for "CTPID-vs-Rest"')
plt.xticks(rotation=90)
plt.show()

# ['CT_Error_1', 'CDWL_Error', 'CT_FAN_SPD_CTRL_1', 'CT_POW_1', 'CT_FAN_SPD_1', 'CWL_SEC_SW_TEMP', 'CWL_SEC_RW_TEMP', 'CT_Eff_1', 'CWL_SEC_CW_FLOW', 'CT_Dist_1', 'Relative_Humidity', 'CT_ApproachTEMP_1', 'CWL_SEC_PM_SPD_1', 'CT_Load_1', 'CWL_SEC_PM_POW_1', 'OA_TEMP', 'CT_SW_TEMP_1']
# Out:
# ['CT_Error_1', 'CDWL_Error', 'CT_FAN_SPD_CTRL_1', 'CT_POW_1', 'CT_FAN_SPD_1', 'CWL_SEC_SW_TEMP', 'CWL_SEC_RW_TEMP', 'CT_Eff_1', 'CWL_SEC_CW_FLOW', 'CT_Dist_1', 'Relative_Humidity', 'CT_ApproachTEMP_1', 'CWL_SEC_PM_SPD_1', 'CT_Load_1', 'CWL_SEC_PM_POW_1', 'OA_TEMP', 'CT_SW_TEMP_1']

# %% [markdown]
# ### Feature Importance Ranking Based Sequential Forward Feature Selection (FIR-SFFS)

# %%
# Stratified 5-Fold Cross-Validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

feature_f1_scores = {}
for n in range(2, 31, 1):  # Change the step size if needed
    X_features = X_train[top_features[:n]]

    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('smote', SMOTE(random_state=42)),
        ('classifier', CatBoostClassifier(random_state=42, verbose=0, thread_count=-1))
    ])

    # Cross-Validation
    cv_results = cross_val_score(pipeline, X_features, y_train_binary, cv=cv, scoring='f1', n_jobs=-1)

    # Mean of F1 scores
    mean_f1_score = np.mean(cv_results)

    # Store the result
    feature_f1_scores[n] = mean_f1_score
    print(f"Top {n} Features: Mean F1 Score = {mean_f1_score:.4f}")

# Convert results to DataFrame
f1_results_df = pd.DataFrame(list(feature_f1_scores.items()), columns=['Num_Features', 'F1_Score'])

# Plot the results
plt.figure(figsize=(10, 5))
plt.plot(f1_results_df['Num_Features'], f1_results_df['F1_Score'], marker='o', linestyle='-')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean (CTPID) F1 Score')
plt.title('F1 Score vs. Number of Features')
plt.show()
# Out:
# Top 2 Features: Mean F1 Score = 0.5578
# Top 3 Features: Mean F1 Score = 0.5878
# Top 4 Features: Mean F1 Score = 0.5885
# Top 5 Features: Mean F1 Score = 0.5883
# Top 6 Features: Mean F1 Score = 0.6180
# Top 7 Features: Mean F1 Score = 0.6325
# Top 8 Features: Mean F1 Score = 0.6334
# Top 9 Features: Mean F1 Score = 0.7313
# Top 10 Features: Mean F1 Score = 0.7321
# Top 11 Features: Mean F1 Score = 0.7409
# Top 12 Features: Mean F1 Score = 0.7427
# Top 13 Features: Mean F1 Score = 0.7431
# Top 14 Features: Mean F1 Score = 0.7456
# Top 15 Features: Mean F1 Score = 0.7414
# Top 16 Features: Mean F1 Score = 0.7573
# Top 17 Features: Mean F1 Score = 0.7580
# Top 18 Features: Mean F1 Score = 0.7559
# Top 19 Features: Mean F1 Score = 0.7568
# Top 20 Features: Mean F1 Score = 0.7563
# Top 21 Features: Mean F1 Score = 0.7553
# Top 22 Features: Mean F1 Score = 0.7504
# Top 23 Features: Mean F1 Score = 0.7496
# Top 24 Features: Mean F1 Score = 0.7492
# Top 25 Features: Mean F1 Score = 0.7509
# Top 26 Features: Mean F1 Score = 0.7517
# Top 27 Features: Mean F1 Score = 0.7497
# Top 28 Features: Mean F1 Score = 0.7498
# Top 29 Features: Mean F1 Score = 0.7503
# Top 30 Features: Mean F1 Score = 0.7490
# '\nTop 8 Features: Mean F1 Score = 0.7468\nTop 9 Features: Mean F1 Score = 0.7472\nTop 10 Features: Mean F1 Score = 0.7454\nTop 11 Features: Mean F1 Score = 0.7485\nTop 12 Features: Mean F1 Score = 0.7490\nTop 13 Features: Mean F1 Score = 0.7489\nTop 14 Features: Mean F1 Score = 0.7473\n'

# %%
# Plot the results
plt.figure(figsize=(10, 5))
plt.plot(f1_results_df['Num_Features'], f1_results_df['F1_Score'], marker='o', linestyle='-')
plt.xlabel('Number of Top Features')
plt.ylabel('Mean (CTPID) F1 Score')
plt.title('F1 Score vs. Number of Features')
plt.axvline(x=17, color='r', linestyle='--') # Peak or Elbow Point
plt.show()

# %% [markdown]
# # Hyper-Parameter Searching

# %%
# GridSearchCV
X_train_features = X_train[top_features[:17]]

param_grid = {
    'classifier__iterations': [750, 1000, 1250],  # Default: 1000
    'classifier__depth': [4, 5, 6],  # Default: 6
    'classifier__learning_rate': [0.01, 0.03, 0.05],  # Default: 0.03
    'classifier__l2_leaf_reg': [2, 3, 4],  # Default: 3
    'classifier__grow_policy': ['SymmetricTree', 'Depthwise'],  # Default: 'SymmetricTree'
    'classifier__subsample': [0.85, 1.0],  # Default: 1.0
}

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('smote', SMOTE(random_state=42)),
    ('classifier', CatBoostClassifier(random_state=42, verbose=0, thread_count=-1))
])

# GridSearchCV
grid_search = GridSearchCV(estimator=pipeline, param_grid=param_grid, n_jobs=-1, scoring='f1', cv=5, verbose=1)
grid_search.fit(X_train_features, y_train_binary)
#best_model = grid_search.best_estimator_

# Results
results_df = pd.DataFrame(grid_search.cv_results_)
results_df = results_df.sort_values(by='mean_test_score', ascending=False)
#print(results_df)

print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best Mean F1 Score (CV): {grid_search.best_score_:.4f}")

"""
Best parameters found: {
'classifier__iterations': 750, 
'classifier__learning_rate': 0.05, 
'classifier__subsample': 0.85}

Best Mean F1 Score (CV): 0.7619
"""
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best parameters found: {'classifier__depth': 6, 'classifier__grow_policy': 'SymmetricTree', 'classifier__iterations': 750, 'classifier__l2_leaf_reg': 3, 'classifier__learning_rate': 0.05, 'classifier__subsample': 0.85}
# Best Mean F1 Score (CV): 0.7619
# "\nBest parameters found: {'classifier__depth': 6, 'classifier__grow_policy': 'Depthwise', 'classifier__iterations': 1250, 'classifier__l2_leaf_reg': 2, 'classifier__learning_rate': 0.01, 'classifier__min_data_in_leaf': 1, 'classifier__subsample': 1.0}\nBest Mean F1 Score (CV): 0.7601\n"
